# %% [markdown]
# # STEP 1: IMPORTING LIBRARIES

# %%
import pandas as pd

import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# # STEP 2: LOADING THE DATASET

# %%
poker_df = pd.read_csv('data/poker_hand_test.data')
poker_df
# Out:
#         1  1.1  1.2  13  2   4  2.1   3  1.3  12  0
# 0       3   12    3   2  3  11    4   5    2   5  1
# 1       1    9    4   6  1   4    3   2    3   9  1
# 2       1    4    3  13  2  13    2   1    3   6  1
# 3       3   10    2   7  1   2    2  11    4   9  0
# 4       1    3    4   5  3   4    1  12    4   6  0
# ...    ..  ...  ...  .. ..  ..  ...  ..  ...  .. ..
# 999994  3    1    1  12  2   9    4   9    2   6  1
# 999995  3    3    4   5  2   7    1   4    4   3  1
# 999996  1   11    4   7  3   9    1  13    2   7  1
# 999997  3   11    1   8  1   1    3  13    2   8  1
# 999998  2    5    2   9  4   9    2   3    3   3  2
#
# [999999 rows x 11 columns]

# %% [markdown]
# # STEP 3: ANALYSING AND PRE-PROCESSING THE DATA

# %% [markdown]
# # STEP 4: CHANGING NAMES OF COLUMN ACCORDING TO THE REFERENCES PROVIDED FROM WHERE THE DATASET IS OBTAINED

# %%
poker_df.columns = ['first_suit', 'first_rank', 'second_suit', 'second_rank', 'third_suit', 'third_rank',
'fourth_suit', 'fourth_rank', 'fifth_suit', 'fifth_rank', 'hand']

labels = ['zilch', 'one_pair', 'two_pair', 'three_of_a_kind', 'straight', 'flush', 'full_house',
'four_of_a_kind', 'straight_flush', 'royal_flush']

poker_df
# Out:
#         first_suit  first_rank  second_suit  second_rank  third_suit  \
# 0                3          12            3            2           3
# 1                1           9            4            6           1
# 2                1           4            3           13           2
# 3                3          10            2            7           1
# 4                1           3            4            5           3
# ...            ...         ...          ...          ...         ...
# 999994           3           1            1           12           2
# 999995           3           3            4            5           2
# 999996           1          11            4            7           3
# 999997           3          11            1            8           1
# 999998           2           5            2            9           4
#
#         third_rank  fourth_suit  fourth_rank  fifth_suit  fifth_rank  hand
# 0               11            4            5           2           5     1
# 1                4            3            2           3           9     1
# 2               13            2            1           3           6     1
# 3                2            2           11           4           9     0
# 4                4            1           12           4           6     0
# ...            ...          ...          ...         ...         ...   ...
# 999994           9            4            9           2           6     1
# 999995           7            1            4           4           3     1
# 999996           9            1           13           2           7     1
# 999997           1            3           13           2           8     1
# 999998           9            2            3           3           3     2
#
# [999999 rows x 11 columns]

# %%
### 4) SEPERATING THE DATASET INTO FEATURES (X) AND TARGET VALUES (y)
X = poker_df.iloc[:, 0:9]
y = poker_df.hand

# %% [markdown]
# # STEP 5: VISUALIZING WHETHER CLASS BALANCE IS PRESENT IN OUR DATASET OR NOT

# %%
pip install yellowbrick
# Out:
# Collecting yellowbrick
#   Downloading yellowbrick-1.5-py3-none-any.whl (282 kB)
#      -------------------------------------- 282.6/282.6 kB 2.5 MB/s eta 0:00:00
# Requirement already satisfied: cycler>=0.10.0 in d:\users\rishav\anaconda3\lib\site-packages (from yellowbrick) (0.11.0)
# Requirement already satisfied: scikit-learn>=1.0.0 in d:\users\rishav\anaconda3\lib\site-packages (from yellowbrick) (1.0.2)
# Requirement already satisfied: matplotlib!=3.0.0,>=2.0.2 in d:\users\rishav\anaconda3\lib\site-packages (from yellowbrick) (3.5.2)
# Requirement already satisfied: numpy>=1.16.0 in d:\users\rishav\anaconda3\lib\site-packages (from yellowbrick) (1.19.5)
# Requirement already satisfied: scipy>=1.0.0 in d:\users\rishav\anaconda3\lib\site-packages (from yellowbrick) (1.9.1)
# Requirement already satisfied: python-dateutil>=2.7 in d:\users\rishav\anaconda3\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in d:\users\rishav\anaconda3\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in d:\users\rishav\anaconda3\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in d:\users\rishav\anaconda3\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (9.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in d:\users\rishav\anaconda3\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\users\rishav\anaconda3\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (1.4.2)
# Requirement already satisfied: joblib>=0.11 in d:\users\rishav\anaconda3\lib\site-packages (from scikit-learn>=1.0.0->yellowbrick) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in d:\users\rishav\anaconda3\lib\site-packages (from scikit-learn>=1.0.0->yellowbrick) (2.2.0)
# Requirement already satisfied: six>=1.5 in d:\users\rishav\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.0.0,>=2.0.2->yellowbrick) (1.16.0)
# Installing collected packages: yellowbrick
# Successfully installed yellowbrick-1.5
# Note: you may need to restart the kernel to use updated packages.

# %%
from yellowbrick.classifier import ClassBalance, ROCAUC, ClassPredictionError

balance = ClassBalance(size=(1080,720), labels=labels)

balance.fit(y)

balance.show()
# Out:
# <AxesSubplot:title={'center':'Class Balance for 999,999 Instances'}, ylabel='support'>

# %% [markdown]
# # STEP 6: UP-SAMPLING FROM MINORITY CLASSES

# %%
poker_df.loc[poker_df['hand']>=5, 'hand'] = 5

y = poker_df.hand

labels = ['zilch', 'one_pair', 'two_pair', 'three_of_a_kind', 'straight', 'flush_or_better']

balance = ClassBalance(size=(1080,720), labels=labels)

balance.fit(y)

balance.show()
# Out:
# <AxesSubplot:title={'center':'Class Balance for 999,999 Instances'}, ylabel='support'>

# %% [markdown]
# # STEP 7: TRAINING THE RANDOM FORESTS CLASSIFIER

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.5)

#CLF = SVC()
CLF = MLPClassifier(solver = 'adam', alpha = 0.05, hidden_layer_sizes=(50, 100, 50), learning_rate = 'adaptive', activation = 'tanh')

CLF.fit(X_train, y_train)
# Out:
# MLPClassifier(activation='tanh', alpha=0.05, hidden_layer_sizes=(50, 100, 50),
#               learning_rate='adaptive')

# %% [markdown]
# # STEP 8: EVALUATING THE MODEL

# %%
#### A) CLASSIFICATION ACCURACY

# %%
from sklearn.metrics import accuracy_score, roc_auc_score, f1_score, recall_score, precision_score

y_pred_test = CLF.predict(X_test)
y_pred_train = CLF.predict(X_train)

print ("Accuracy of the Model on Train Data is : {}".format(accuracy_score(y_train, y_pred_train)))
print ("Accuracy of the Model on Test Data is : {}".format(accuracy_score(y_test, y_pred_test)))
# Out:
# Accuracy of the Model on Train Data is : 0.7737775475550951
# Accuracy of the Model on Test Data is : 0.773456

# %%
pip install yellowbrick --upgrade
# Out:
# Requirement already satisfied: yellowbrick in d:\users\rishav\anaconda3\lib\site-packages (1.5)
# Requirement already satisfied: scipy>=1.0.0 in d:\users\rishav\anaconda3\lib\site-packages (from yellowbrick) (1.9.1)
# Requirement already satisfied: cycler>=0.10.0 in d:\users\rishav\anaconda3\lib\site-packages (from yellowbrick) (0.11.0)
# Requirement already satisfied: scikit-learn>=1.0.0 in d:\users\rishav\anaconda3\lib\site-packages (from yellowbrick) (1.0.2)
# Requirement already satisfied: numpy>=1.16.0 in d:\users\rishav\anaconda3\lib\site-packages (from yellowbrick) (1.19.5)
# Requirement already satisfied: matplotlib!=3.0.0,>=2.0.2 in d:\users\rishav\anaconda3\lib\site-packages (from yellowbrick) (3.5.2)
# Requirement already satisfied: pyparsing>=2.2.1 in d:\users\rishav\anaconda3\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\users\rishav\anaconda3\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (1.4.2)
# Requirement already satisfied: fonttools>=4.22.0 in d:\users\rishav\anaconda3\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (4.25.0)
# Requirement already satisfied: pillow>=6.2.0 in d:\users\rishav\anaconda3\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (9.2.0)
# Requirement already satisfied: packaging>=20.0 in d:\users\rishav\anaconda3\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in d:\users\rishav\anaconda3\lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (2.8.2)
# Requirement already satisfied: joblib>=0.11 in d:\users\rishav\anaconda3\lib\site-packages (from scikit-learn>=1.0.0->yellowbrick) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in d:\users\rishav\anaconda3\lib\site-packages (from scikit-learn>=1.0.0->yellowbrick) (2.2.0)
# Requirement already satisfied: six>=1.5 in d:\users\rishav\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.0.0,>=2.0.2->yellowbrick) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
### B) ROC CURVE AND AUC:
from yellowbrick.classifier import ROCAUC

rocauc = ROCAUC(CLF, size =(1080, 720), classes = labels, target_type="binary")

rocauc.score(X_test, y_test)
rocauc.show()
# Out:
# D:\Users\Rishav\anaconda3\lib\site-packages\yellowbrick\classifier\base.py:232: YellowbrickWarning: could not determine class_counts_ from previously fitted classifier
#   warnings.warn(
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# D:\Users\Rishav\anaconda3\lib\site-packages\yellowbrick\utils\wrapper.py in __getattr__(self, attr)
#      47         try:
# ---> 48             return getattr(self._wrapped, attr)
#      49         except AttributeError as e:
#
# AttributeError: 'MLPClassifier' object has no attribute 'target_type_'
#
# The above exception was the direct cause of the following exception:
#
# YellowbrickAttributeError                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6028\12187204.py in <module>
#       4 rocauc = ROCAUC(CLF, size =(1080, 720), classes = labels, target_type="binary")
#       5
# ----> 6 rocauc.score(X_test, y_test)
#       7 rocauc.show()
#
# D:\Users\Rishav\anaconda3\lib\site-packages\yellowbrick\classifier\rocauc.py in score(self, X, y)
#     267         y_pred = self._get_y_scores(X)
#     268
# --> 269         if self.target_type_ == BINARY:
#     270             # For binary, per_class must be True to draw micro/macro curves
#     271             if (self.micro or self.macro) and not self.per_class:
#
# D:\Users\Rishav\anaconda3\lib\site-packages\yellowbrick\utils\wrapper.py in __getattr__(self, attr)
#      48             return getattr(self._wrapped, attr)
#      49         except AttributeError as e:
# ---> 50             raise YellowbrickAttributeError(f"neither visualizer '{self.__class__.__name__}' nor wrapped estimator '{type(self._wrapped).__name__}' have attribute '{attr}'") from e
#
# YellowbrickAttributeError: neither visualizer 'ROCAUC' nor wrapped estimator 'MLPClassifier' have attribute 'target_type_'

# %% [markdown]
# # STEP 9: CLASSIFICATION REPORT HEATMAP

# %%
from yellowbrick.classifier import ClassificationReport

report = ClassificationReport(CLF, size = (720, 640), classes = labels, cmap = 'PuBu')
report.score(X_test, y_test)
report.show()
# Out:
# D:\Users\Rishav\anaconda3\lib\site-packages\yellowbrick\classifier\base.py:232: YellowbrickWarning: could not determine class_counts_ from previously fitted classifier
#   warnings.warn(
# D:\Users\Rishav\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# <AxesSubplot:title={'center':'MLPClassifier Classification Report'}>

# %% [markdown]
# # STEP 10: CLASS PREDICTION ERROR

# %%
error = ClassPredictionError(CLF, size= [1080, 720], classes = labels)
error.score(X_test, y_test)
error.poof()
# Out:
# D:\Users\Rishav\anaconda3\lib\site-packages\yellowbrick\classifier\base.py:232: YellowbrickWarning: could not determine class_counts_ from previously fitted classifier
#   warnings.warn(
# <AxesSubplot:title={'center':'Class Prediction Error for MLPClassifier'}, xlabel='actual class', ylabel='number of predicted class'>
